# %%
import requests
import json

new = requests.get('https://api.polygon.io/v2/aggs/ticker/AAPL/range/1/day/2020-06-01/2020-06-17?apiKey=wyH5CtMCMqfAvDO45asBYfYnOWwMlQCC')
data=new.json()

# %%
data['results']
# Out:
# [{'v': 81000752.0,
#   'vw': 80.2125,
#   'o': 79.4375,
#   'c': 80.4625,
#   'h': 80.5875,
#   'l': 79.3025,
#   't': 1591041600000,
#   'n': 231707},
#  {'v': 87642632.0,
#   'vw': 80.3801,
#   'o': 80.1863,
#   'c': 80.835,
#   'h': 80.86,
#   'l': 79.7325,
#   't': 1591128000000,
#   'n': 226248},
#  {'v': 104490584.0,
#   'vw': 81.084,
#   'o': 81.165,
#   'c': 81.28,
#   'h': 81.55,
#   'l': 80.575,
#   't': 1591214400000,
#   'n': 258867},
#  {'v': 87560364.0,
#   'vw': 80.8328,
#   'o': 81.0975,
#   'c': 80.58,
#   'h': 81.405,
#   'l': 80.195,
#   't': 1591300800000,
#   'n': 237171},
#  {'v': 137248048.0,
#   'vw': 82.2786,
#   'o': 80.8375,
#   'c': 82.875,
#   'h': 82.9375,
#   'l': 80.8075,
#   't': 1591387200000,
#   'n': 351615},
#  {'v': 95650900.0,
#   'vw': 82.7662,
#   'o': 82.5625,
#   'c': 83.365,
#   'h': 83.4,
#   'l': 81.83,
#   't': 1591646400000,
#   'n': 261203},
#  {'v': 147712228.0,
#   'vw': 85.3634,
#   'o': 83.035,
#   'c': 85.9975,
#   'h': 86.4025,
# ...
